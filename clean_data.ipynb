# %%
import pandas as pd
df2 = pd.read_csv("imdb_movies_no_selenium.csv",index_col=0)
df2
# Out:
#                             title           director release_year   length  \
# 0        The Shawshank Redemption     Frank Darabont       (1994)  142 min
# 1                 The Dark Knight  Christopher Nolan       (2008)  152 min
# 2                       Inception  Christopher Nolan       (2010)  148 min
# 3                      Fight Club      David Fincher       (1999)  139 min
# 4                    Forrest Gump    Robert Zemeckis       (1994)  142 min
# ...                           ...                ...          ...      ...
# 54444  Terminator 2: Judgment Day      James Cameron       (1991)  137 min
# 54445      Avengers: Infinity War      Anthony Russo       (2018)  149 min
# 54446             The Truman Show         Peter Weir       (1998)  103 min
# 54447          The Usual Suspects       Bryan Singer       (1995)  106 min
# 54448               The Lion King       Roger Allers       (1994)   88 min
#
# ...

# %%
df2_no_NaN = df2.dropna()
df2_no_NaN
# Out:
#                             title           director release_year   length  \
# 0        The Shawshank Redemption     Frank Darabont       (1994)  142 min
# 1                 The Dark Knight  Christopher Nolan       (2008)  152 min
# 2                       Inception  Christopher Nolan       (2010)  148 min
# 3                      Fight Club      David Fincher       (1999)  139 min
# 4                    Forrest Gump    Robert Zemeckis       (1994)  142 min
# ...                           ...                ...          ...      ...
# 54444  Terminator 2: Judgment Day      James Cameron       (1991)  137 min
# 54445      Avengers: Infinity War      Anthony Russo       (2018)  149 min
# 54446             The Truman Show         Peter Weir       (1998)  103 min
# 54447          The Usual Suspects       Bryan Singer       (1995)  106 min
# 54448               The Lion King       Roger Allers       (1994)   88 min
#
# ...

# %%
df2_no_NaN['release_year'] = df2_no_NaN['release_year'].str[1:-1]
df2_no_NaN['gross_US_CA'] = df2_no_NaN['gross_US_CA'].str[1:-1]
df2_no_NaN['length'] = df2_no_NaN['length'].str[:-3]
df2_no_NaN
# Out:
# C:\Users\Chloe\AppData\Local\Temp\ipykernel_22048\2040571878.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_no_NaN['release_year'] = df2_no_NaN['release_year'].str[1:-1]
# C:\Users\Chloe\AppData\Local\Temp\ipykernel_22048\2040571878.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_no_NaN['gross_US_CA'] = df2_no_NaN['gross_US_CA'].str[1:-1]
# C:\Users\Chloe\AppData\Local\Temp\ipykernel_22048\2040571878.py:3: SettingWithCopyWarning:
# ...

# %%
df2_no_NaN.to_csv("imdb_movies_cleaned.csv")
