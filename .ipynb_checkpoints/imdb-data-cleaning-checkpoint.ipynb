# %%
import pandas as pd
df2 = pd.read_csv("imdb_movies2.csv",index_col=0)
df2
# Out:
#                                    title           director release_year  \
# 0               The Shawshank Redemption     Frank Darabont       (1994)
# 1                        The Dark Knight  Christopher Nolan       (2008)
# 2                              Inception  Christopher Nolan       (2010)
# 3                             Fight Club      David Fincher       (1999)
# 4                           Forrest Gump    Robert Zemeckis       (1994)
# ...                                  ...                ...          ...
# 44370                    Silence and Cry      Miklós Jancsó       (1968)
# 44371  What the Constitution Means to Me    Marielle Heller       (2020)
# 44372                         Ranarangam      Sudheer Varma       (2019)
# 44373                  Christmas Harmony       Nanea Miyata       (2018)
# 44374             The Chanting Revisited    Rizal Mantovani       (2018)
#
#         length                      genre  imdb_score     rating gross_US_CA  \
# ...

# %%
df3 = pd.read_csv("imdb_movies3.csv",index_col=0)
df3
# Out:
# C:\Users\Chloe\AppData\Local\Temp\ipykernel_21756\2453647018.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df3 = pd.read_csv("imdb_movies3.csv",index_col=0)
#                          title           director release_year   length  \
# 0                   Foodfight!  Lawrence Kasanoff       (2012)   91 min
# 1                 Sink or Swim   Gilles Lellouche       (2018)  121 min
# 2                 The Best Man     Malcolm D. Lee       (1999)  120 min
# 3       City of Life and Death           Chuan Lu       (2009)  133 min
# 4                  Delta Farce       C.B. Harding       (2007)   90 min
# ...                        ...                ...          ...      ...
# 75045      La vida sigue igual     Eugenio Martín       (1969)   91 min
# 75046             The Maneater    Natalie Saracco       (2012)   85 min
# 75047        Monsieur Hawarden        Harry Kümel       (1968)  109 min
# ...

# %%
df4 = pd.read_csv("imdb_movies4.csv",index_col=0)
df4
# Out:
#                                                title             director  \
# 0                                   Aakasha Mittayee        M. Padmakumar
# 1                                    Eureka Stockade           Harry Watt
# 2                                     The Delinquent           Cheh Chang
# 3                                        Around June         James Savoca
# 4                                            Twisted  Seth Michael Donsky
# ...                                              ...                  ...
# 40045         Royal Shakespeare Company: The Tempest        Gregory Doran
# 40046  Looking for a Lady with Fangs and a Moustache       Khyentse Norbu
# 40047                            Between the Seasons           Junsik Kim
# 40048                              Un amour interdit  Jean-Pierre Dougnac
# 40049                             Emanuelle e Lolita           Henri Sala
#
#       release_year   length                      genre  imdb_score     rating  \
# ...

# %%
df_final = pd.concat([df2, df3, df4], ignore_index=True).drop_duplicates()
df_final.reset_index(inplace =True, drop=True)
df_final
# Out:
#                                                 title             director  \
# 0                            The Shawshank Redemption       Frank Darabont
# 1                                     The Dark Knight    Christopher Nolan
# 2                                           Inception    Christopher Nolan
# 3                                          Fight Club        David Fincher
# 4                                        Forrest Gump      Robert Zemeckis
# ...                                               ...                  ...
# 125844         Royal Shakespeare Company: The Tempest        Gregory Doran
# 125845  Looking for a Lady with Fangs and a Moustache       Khyentse Norbu
# 125846                            Between the Seasons           Junsik Kim
# 125847                              Un amour interdit  Jean-Pierre Dougnac
# 125848                             Emanuelle e Lolita           Henri Sala
#
# ...

# %%
df_final.to_csv("imdb_movies_FINAL.csv")

# %%
df_final_no_NaN = df_final.dropna()
df_final_no_NaN
# Out:
#                            title           director release_year   length  \
# 0       The Shawshank Redemption     Frank Darabont       (1994)  142 min
# 1                The Dark Knight  Christopher Nolan       (2008)  152 min
# 2                      Inception  Christopher Nolan       (2010)  148 min
# 3                     Fight Club      David Fincher       (1999)  139 min
# 4                   Forrest Gump    Robert Zemeckis       (1994)  142 min
# ...                          ...                ...          ...      ...
# 123755            Ghetto Physics      William Arntz       (2010)   94 min
# 124760                Scavengers      Dee McLachlan       (1988)   89 min
# 125147                  The Minx     Raymond Jacobs       (1969)   84 min
# 125357              Da jiao long          Chien Lei       (1974)  101 min
# 125430             Big Ain't Bad      Ray Culpepper       (2002)  108 min
#
#                             genre  imdb_score rating gross_US_CA imdb_votes
# ...

# %%
df_final_no_NaN['release_year'] = df_final_no_NaN['release_year'].str[1:-1]
df_final_no_NaN['gross_US_CA'] = df_final_no_NaN['gross_US_CA'].str[1:-1]
df_final_no_NaN['length'] = df_final_no_NaN['length'].str[:-3]
df2_no_NaN
# Out:
# C:\Users\Chloe\AppData\Local\Temp\ipykernel_21756\3410553576.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final_no_NaN['release_year'] = df_final_no_NaN['release_year'].str[1:-1]
# C:\Users\Chloe\AppData\Local\Temp\ipykernel_21756\3410553576.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final_no_NaN['gross_US_CA'] = df_final_no_NaN['gross_US_CA'].str[1:-1]
# C:\Users\Chloe\AppData\Local\Temp\ipykernel_21756\3410553576.py:3: SettingWithCopyWarning:
# ...

# %%
df_final_no_NaN.to_csv("imdb_movies_FINAL_NO_NAN_CLEANED.csv")

# %%
df_final['release_year'] = df_final['release_year'].str[1:-1]
df_final['gross_US_CA'] = df_final['gross_US_CA'].str[1:-1]
df_final['length'] = df_final['length'].str[:-3]
df_final
# Out:
#                                                 title             director  \
# 0                            The Shawshank Redemption       Frank Darabont
# 1                                     The Dark Knight    Christopher Nolan
# 2                                           Inception    Christopher Nolan
# 3                                          Fight Club        David Fincher
# 4                                        Forrest Gump      Robert Zemeckis
# ...                                               ...                  ...
# 125844         Royal Shakespeare Company: The Tempest        Gregory Doran
# 125845  Looking for a Lady with Fangs and a Moustache       Khyentse Norbu
# 125846                            Between the Seasons           Junsik Kim
# 125847                              Un amour interdit  Jean-Pierre Dougnac
# 125848                             Emanuelle e Lolita           Henri Sala
#
# ...

# %%
df_final.to_csv("imdb_movies_FINAL_CLEANED.csv")
